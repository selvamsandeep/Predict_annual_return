# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import  r2_score
from scipy import sparse as ssp


import lightgbm as lgb
from subprocess import check_output
print(check_output(['ls','input']).decode('utf8'))
# Out:
# sample_submission.csv
# test.csv
# train.csv

# %%
def lgb_r2(pred, drain):
    y = drain.get_label()
    score = r2_score(y, pred)
    return 'r2_score', score, True

cv_only = True
save_cv = True
full_train = False
NFOLDS = 5
kfold = KFold(n_splits=NFOLDS, shuffle=True, random_state=13)

# %%
train = pd.read_csv('input/train.csv', parse_dates=['start_date','creation_date','sell_date'])
test = pd.read_csv('input/test.csv', parse_dates=['start_date','creation_date','sell_date'])

print('Train data size: {} Test data size: {}'.format(train.shape, test.shape))
# Out:
# Train data size: (9366, 18) Test data size: (4801, 17)

# %%
train['missing'] = train.isnull().sum(axis=1).astype(float)
test['missing'] = test.isnull().sum(axis=1).astype(float)

# %%
train['desk_id'].fillna('DSK00000099', inplace=True)
test['desk_id'].fillna('DSK00000099', inplace=True)

train['desk_id']=train.desk_id.apply(lambda x : x[-4:]).astype(np.int16)
test['desk_id']=test.desk_id.apply(lambda x : x[-4:]).astype(np.int16)

# %%
cat_features = []
le = LabelEncoder()
le.fit(train['office_id'])
train['office_id'] = le.transform(train['office_id'])
test['office_id'] = le.transform(test['office_id'])
cat_features.append('office_id')

# %%
le.fit(train['pf_category'])
train['pf_category'] = le.transform(train['pf_category'])
test['pf_category'] = le.transform(test['pf_category'])
cat_features.append('pf_category')

# %%
le.fit(train['country_code'])
train['country_code'] = le.transform(train['country_code'])
test['country_code'] = le.transform(test['country_code'])
cat_features.append('country_code')

# %%
le.fit(train['currency'])
train['currency'] = le.transform(train['currency'])
test['currency'] = le.transform(test['currency'])
cat_features.append('currency')

# %%
train['indicator_code'] = train['indicator_code'].apply(lambda x : 0 if x==False else 1 if x== True else 2)
test['indicator_code']= test['indicator_code'].apply(lambda x : 0 if x==False else 1 if x== True else 2)
cat_features.append('indicator_code')

# %%
le.fit(train['type'])
train['type'] = le.transform(train['type'])
test['type'] = le.transform(test['type'])
cat_features.append('type')

# %%
train['hedge_value'] = train['hedge_value'].apply(lambda x : 0 if x==False else 1 if x== True else 2)
test['hedge_value'] = test['hedge_value'].apply(lambda x : 0 if x==False else 1 if x== True else 2)
cat_features.append('hedge_value')

# %%
train['status'] = train['status'].apply(lambda x : 0 if x==False else 1 if x== True else 2)
test['status'] = test['status'].apply(lambda x : 0 if x==False else 1 if x== True else 2)
cat_features.append('status')

# %%
enc = OneHotEncoder()
enc.fit(train[cat_features])
train_cat = enc.transform(train[cat_features])
test_cat = enc.transform(test[cat_features])

# %%
cat_count_features = []
for c in cat_features:
    d = pd.concat([train[c],test[c]]).value_counts().to_dict()
    train['%s_count'%c] = train[c].apply(lambda x:d.get(x,0))
    test['%s_count'%c] = test[c].apply(lambda x:d.get(x,0))
    cat_count_features.append('%s_count'%c)

# %%
data_all =[train, test]

# %%
for data in data_all:
    data['start_day'] = data.start_date.dt.day
    data['start_month'] = data.start_date.dt.month
    data['start_year'] = data.start_date.dt.year
    
    data['creation_day'] = data.creation_date.dt.day
    data['creation_month'] = data.creation_date.dt.month
    data['creation_year'] = data.creation_date.dt.year
    
    data['sell_day'] = data.sell_date.dt.day
    data['sell_month'] = data.sell_date.dt.month
    data['sell_year'] = data.start_date.dt.year
    
    data['start_creation'] = (data.start_date - data.creation_date).dt.days
    data['start_sell'] = (data.start_date - data.sell_date).dt.days
    data['creation_sell'] = (data.creation_date - data.sell_date).dt.days
    
    data['sold'].fillna(68552000.0, inplace= True)
    data['dff_sold_bought'] = (data.sold - data.bought)
    data['gain_loss'] = data.dff_sold_bought * data.euribor_rate 
    data['libor_rate'].fillna(0.0, inplace= True)
    data.drop(['start_date','creation_date', 'sell_date'], inplace=True, axis=1)

# %%
date_features = ['start_day','start_month','start_year','creation_day','creation_month','creation_year',
                'sell_day', 'sell_month']
amt_features = ['sold', 'bought', 'euribor_rate', 'libor_rate','dff_sold_bought','gain_loss' ]

# %%
train_label = train['return']
test_portfolio_id = test.portfolio_id.values
train_portfolio_id = train.portfolio_id.values

train.drop(['portfolio_id', 'return'], inplace=True, axis=1)
test.drop(['portfolio_id'], inplace=True, axis=1)

# %%
train_list = [train[cat_count_features + date_features+amt_featues].values, train_cat]
test_list = [test[cat_count_features + date_features+amt_featues].values, test_cat]

X = ssp.hstack(train_list).tocsr()
X_test = ssp.hstack(test_list).tocsr()

# %%
params = {'learning_rate': 0.04, 
          'num_leaves':78,
          'min_data_in_leaf': 160,
          'max_depth': 6, 
          'max_bin': 50,
          'colsample_bytree': 0.522,
          'boosting': 'gbdt', 
          'application': 'regression', 
          'min_child_samples': 10,
          #'min_child_weight': 150,
          'min_split_gain': 0,
          'subsample': 0.9,
          #'metric': 'mae',  
          'verbosity': 0,
          }
num_boost_round = 10000

# %%
x_score = []
final_cv_train = np.zeros(len(train_label))
final_cv_pred = np.zeros(len(test_portfolio_id))

# %%
for s in range(16):
    cv_train = np.zeros(len(train_label))
    cv_pred = np.zeros(len(test_portfolio_id))

    params['seed'] = s

    if cv_only:
        kf = kfold.split(X, train_label)

        best_trees = []
        fold_scores = []

        for i, (train_fold, valid_fold) in enumerate(kf):
            X_train, X_valid, y_train, y_valid = \
                X[train_fold, :], X[valid_fold, :], train_label[train_fold], train_label[valid_fold]
                
            dtrain = lgb.Dataset(X_train, y_train)
            dvalid = lgb.Dataset(X_valid, y_valid, reference=dtrain)
            
            bst = lgb.train(params, dtrain, num_boost_round, valid_sets=dvalid, feval=lgb_r2, verbose_eval=100,
                             early_stopping_rounds=100)            
            best_trees.append(bst.best_iteration)
            
            model = lgb.train(params,lgb.Dataset(X, train_label), num_boost_round=bst.best_iteration)
            cv_pred += model.predict(X_test)
            cv_train[valid_fold] += model.predict(X_valid)
            
            #cv_pred += bst.predict(X_test, num_iteration=bst.best_iteration)
            #cv_train[valid_fold] += bst.predict(X_valid)

            score = r2_score(y_valid, cv_train[valid_fold])
            print(score)
            fold_scores.append(score)

        cv_pred /= NFOLDS
        final_cv_train += cv_train
        final_cv_pred += cv_pred

        print("cv score:")
        print(r2_score(train_label, cv_train))
        print ("current score: {}, {}".format(r2_score(train_label, final_cv_train / (s + 1.)), s+1))
        print(fold_scores)
        print(best_trees, np.mean(best_trees))

        x_score.append(r2_score(train_label, cv_train))

print(x_score)
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.957915
# [200]	valid_0's r2_score: 0.966054
# [300]	valid_0's r2_score: 0.969574
# [400]	valid_0's r2_score: 0.970262
# [500]	valid_0's r2_score: 0.971126
# [600]	valid_0's r2_score: 0.971372
# [700]	valid_0's r2_score: 0.971604
# [800]	valid_0's r2_score: 0.971653
# Early stopping, best iteration is:
# [749]	valid_0's r2_score: 0.971886
# 0.983839411654
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.905298
# [200]	valid_0's r2_score: 0.912348
# [300]	valid_0's r2_score: 0.915459
# [400]	valid_0's r2_score: 0.916788
# [500]	valid_0's r2_score: 0.917395
# [600]	valid_0's r2_score: 0.917836
# [700]	valid_0's r2_score: 0.918138
# [800]	valid_0's r2_score: 0.918233
# [900]	valid_0's r2_score: 0.918372
# [1000]	valid_0's r2_score: 0.918555
# [1100]	valid_0's r2_score: 0.918606
# [1200]	valid_0's r2_score: 0.918707
# [1300]	valid_0's r2_score: 0.918667
# [1400]	valid_0's r2_score: 0.918831
# Early stopping, best iteration is:
# [1399]	valid_0's r2_score: 0.918851
# 0.949541819123
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.507199
# [200]	valid_0's r2_score: 0.511614
# [300]	valid_0's r2_score: 0.513514
# [400]	valid_0's r2_score: 0.515244
# [500]	valid_0's r2_score: 0.516827
# [600]	valid_0's r2_score: 0.518359
# [700]	valid_0's r2_score: 0.519096
# [800]	valid_0's r2_score: 0.519791
# [900]	valid_0's r2_score: 0.520561
# [1000]	valid_0's r2_score: 0.520865
# [1100]	valid_0's r2_score: 0.521365
# [1200]	valid_0's r2_score: 0.521841
# [1300]	valid_0's r2_score: 0.52193
# [1400]	valid_0's r2_score: 0.522326
# [1500]	valid_0's r2_score: 0.522592
# [1600]	valid_0's r2_score: 0.52259
# Early stopping, best iteration is:
# [1546]	valid_0's r2_score: 0.522725
# 0.678025755852
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.943485
# [200]	valid_0's r2_score: 0.950825
# [300]	valid_0's r2_score: 0.952888
# [400]	valid_0's r2_score: 0.953492
# [500]	valid_0's r2_score: 0.953853
# Early stopping, best iteration is:
# [479]	valid_0's r2_score: 0.953958
# 0.968332496745
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.911331
# [200]	valid_0's r2_score: 0.914074
# Early stopping, best iteration is:
# [173]	valid_0's r2_score: 0.914261
# 0.926241587595
# cv score:
# 0.867181051438
# current score: 0.8671810514378863, 1
# [0.98383941165413635, 0.94954181912294733, 0.6780257558522178, 0.96833249674501543, 0.92624158759485642]
# [749, 1399, 1546, 479, 173] 869.2
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.958141
# [200]	valid_0's r2_score: 0.966527
# [300]	valid_0's r2_score: 0.969006
# [400]	valid_0's r2_score: 0.969963
# [500]	valid_0's r2_score: 0.970541
# [600]	valid_0's r2_score: 0.971323
# [700]	valid_0's r2_score: 0.971636
# [800]	valid_0's r2_score: 0.971859
# [900]	valid_0's r2_score: 0.971915
# Early stopping, best iteration is:
# [815]	valid_0's r2_score: 0.971987
# 0.984854335549
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.908045
# [200]	valid_0's r2_score: 0.914327
# [300]	valid_0's r2_score: 0.916417
# [400]	valid_0's r2_score: 0.917812
# [500]	valid_0's r2_score: 0.918565
# [600]	valid_0's r2_score: 0.918613
# [700]	valid_0's r2_score: 0.918979
# [800]	valid_0's r2_score: 0.919285
# [900]	valid_0's r2_score: 0.919288
# [1000]	valid_0's r2_score: 0.919279
# [1100]	valid_0's r2_score: 0.91937
# [1200]	valid_0's r2_score: 0.919441
# [1300]	valid_0's r2_score: 0.919467
# [1400]	valid_0's r2_score: 0.919494
# Early stopping, best iteration is:
# [1373]	valid_0's r2_score: 0.919546
# 0.94916504161
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.508176
# [200]	valid_0's r2_score: 0.51245
# [300]	valid_0's r2_score: 0.514216
# [400]	valid_0's r2_score: 0.515922
# [500]	valid_0's r2_score: 0.517118
# [600]	valid_0's r2_score: 0.518566
# [700]	valid_0's r2_score: 0.519494
# [800]	valid_0's r2_score: 0.520064
# [900]	valid_0's r2_score: 0.520593
# [1000]	valid_0's r2_score: 0.521191
# [1100]	valid_0's r2_score: 0.521486
# [1200]	valid_0's r2_score: 0.521818
# [1300]	valid_0's r2_score: 0.522161
# [1400]	valid_0's r2_score: 0.522502
# [1500]	valid_0's r2_score: 0.52291
# [1600]	valid_0's r2_score: 0.523073
# [1700]	valid_0's r2_score: 0.523027
# Early stopping, best iteration is:
# [1614]	valid_0's r2_score: 0.523117
# 0.684365678958
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.944417
# [200]	valid_0's r2_score: 0.950996
# [300]	valid_0's r2_score: 0.952974
# [400]	valid_0's r2_score: 0.953344
# [500]	valid_0's r2_score: 0.953549
# [600]	valid_0's r2_score: 0.953544
# Early stopping, best iteration is:
# [552]	valid_0's r2_score: 0.953725
# 0.969129824169
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.911923
# [200]	valid_0's r2_score: 0.915162
# [300]	valid_0's r2_score: 0.915377
# Early stopping, best iteration is:
# [278]	valid_0's r2_score: 0.915633
# 0.931758893106
# cv score:
# 0.87039424117
# current score: 0.8689894453225879, 2
# [0.98485433554946411, 0.94916504160978354, 0.68436567895807476, 0.96912982416916371, 0.93175889310614513]
# [815, 1373, 1614, 552, 278] 926.4
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.959062
# [200]	valid_0's r2_score: 0.96684
# [300]	valid_0's r2_score: 0.969269
# [400]	valid_0's r2_score: 0.970501
# [500]	valid_0's r2_score: 0.971176
# [600]	valid_0's r2_score: 0.971888
# [700]	valid_0's r2_score: 0.972103
# [800]	valid_0's r2_score: 0.972054
# Early stopping, best iteration is:
# [707]	valid_0's r2_score: 0.97215
# 0.98411158431
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.907303
# [200]	valid_0's r2_score: 0.913225
# [300]	valid_0's r2_score: 0.916027
# [400]	valid_0's r2_score: 0.91721
# [500]	valid_0's r2_score: 0.91792
# [600]	valid_0's r2_score: 0.918485
# [700]	valid_0's r2_score: 0.918812
# [800]	valid_0's r2_score: 0.91907
# Early stopping, best iteration is:
# [796]	valid_0's r2_score: 0.91908
# 0.94135591693
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.509126
# [200]	valid_0's r2_score: 0.512978
# [300]	valid_0's r2_score: 0.51413
# [400]	valid_0's r2_score: 0.515408
# [500]	valid_0's r2_score: 0.516381
# [600]	valid_0's r2_score: 0.517416
# [700]	valid_0's r2_score: 0.518374
# [800]	valid_0's r2_score: 0.519066
# [900]	valid_0's r2_score: 0.519343
# [1000]	valid_0's r2_score: 0.520178
# [1100]	valid_0's r2_score: 0.52038
# [1200]	valid_0's r2_score: 0.520951
# [1300]	valid_0's r2_score: 0.521505
# [1400]	valid_0's r2_score: 0.521998
# [1500]	valid_0's r2_score: 0.522184
# [1600]	valid_0's r2_score: 0.522217
# [1700]	valid_0's r2_score: 0.522561
# [1800]	valid_0's r2_score: 0.522518
# Early stopping, best iteration is:
# [1721]	valid_0's r2_score: 0.52261
# 0.690033975767
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.944613
# [200]	valid_0's r2_score: 0.951776
# [300]	valid_0's r2_score: 0.954119
# [400]	valid_0's r2_score: 0.954762
# [500]	valid_0's r2_score: 0.954725
# [600]	valid_0's r2_score: 0.954635
# Early stopping, best iteration is:
# [545]	valid_0's r2_score: 0.954867
# 0.969277674423
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.911921
# [200]	valid_0's r2_score: 0.914503
# [300]	valid_0's r2_score: 0.914972
# Early stopping, best iteration is:
# [298]	valid_0's r2_score: 0.915
# 0.933201769094
# cv score:
# 0.870890722719
# current score: 0.8697695445631795, 3
# [0.98411158430953749, 0.9413559169301895, 0.69003397576726155, 0.9692776744232795, 0.93320176909422337]
# [707, 796, 1721, 545, 298] 813.4
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.959471
# [200]	valid_0's r2_score: 0.966703
# [300]	valid_0's r2_score: 0.969705
# [400]	valid_0's r2_score: 0.970754
# [500]	valid_0's r2_score: 0.971779
# [600]	valid_0's r2_score: 0.972531
# [700]	valid_0's r2_score: 0.972717
# Early stopping, best iteration is:
# [693]	valid_0's r2_score: 0.972793
# 0.983859672934
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.90574
# [200]	valid_0's r2_score: 0.912766
# [300]	valid_0's r2_score: 0.915425
# [400]	valid_0's r2_score: 0.916815
# [500]	valid_0's r2_score: 0.917372
# [600]	valid_0's r2_score: 0.917813
# [700]	valid_0's r2_score: 0.918039
# Early stopping, best iteration is:
# [673]	valid_0's r2_score: 0.918061
# 0.937850124219
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.508584
# [200]	valid_0's r2_score: 0.513336
# [300]	valid_0's r2_score: 0.515406
# [400]	valid_0's r2_score: 0.517869
# [500]	valid_0's r2_score: 0.519021
# [600]	valid_0's r2_score: 0.519703
# [700]	valid_0's r2_score: 0.520407
# [800]	valid_0's r2_score: 0.521125
# [900]	valid_0's r2_score: 0.521435
# [1000]	valid_0's r2_score: 0.521791
# [1100]	valid_0's r2_score: 0.522368
# [1200]	valid_0's r2_score: 0.523033
# [1300]	valid_0's r2_score: 0.523178
# [1400]	valid_0's r2_score: 0.523544
# [1500]	valid_0's r2_score: 0.523728
# [1600]	valid_0's r2_score: 0.523709
# [1700]	valid_0's r2_score: 0.523812
# [1800]	valid_0's r2_score: 0.524043
# [1900]	valid_0's r2_score: 0.523949
# Early stopping, best iteration is:
# [1856]	valid_0's r2_score: 0.524145
# 0.698755032429
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.944146
# [200]	valid_0's r2_score: 0.951549
# [300]	valid_0's r2_score: 0.954074
# [400]	valid_0's r2_score: 0.954832
# [500]	valid_0's r2_score: 0.955105
# [600]	valid_0's r2_score: 0.954962
# Early stopping, best iteration is:
# [505]	valid_0's r2_score: 0.955153
# 0.968634220421
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.911697
# [200]	valid_0's r2_score: 0.915282
# Early stopping, best iteration is:
# [188]	valid_0's r2_score: 0.915425
# 0.926116049706
# cv score:
# 0.871607514301
# current score: 0.8703822592242776, 4
# [0.98385967293351051, 0.93785012421875125, 0.6987550324289471, 0.96863422042050118, 0.92611604970618078]
# [693, 673, 1856, 505, 188] 783.0
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.960192
# [200]	valid_0's r2_score: 0.967377
# [300]	valid_0's r2_score: 0.969894
# [400]	valid_0's r2_score: 0.970952
# [500]	valid_0's r2_score: 0.971911
# [600]	valid_0's r2_score: 0.972373
# [700]	valid_0's r2_score: 0.972557
# Early stopping, best iteration is:
# [673]	valid_0's r2_score: 0.972686
# 0.984118328162
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.907932
# [200]	valid_0's r2_score: 0.914294
# [300]	valid_0's r2_score: 0.916733
# [400]	valid_0's r2_score: 0.918256
# [500]	valid_0's r2_score: 0.918598
# [600]	valid_0's r2_score: 0.918723
# [700]	valid_0's r2_score: 0.919237
# [800]	valid_0's r2_score: 0.919417
# [900]	valid_0's r2_score: 0.919759
# [1000]	valid_0's r2_score: 0.919822
# [1100]	valid_0's r2_score: 0.919788
# Early stopping, best iteration is:
# [1026]	valid_0's r2_score: 0.919908
# 0.945079227961
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.508874
# [200]	valid_0's r2_score: 0.513018
# [300]	valid_0's r2_score: 0.514821
# [400]	valid_0's r2_score: 0.516859
# [500]	valid_0's r2_score: 0.518264
# [600]	valid_0's r2_score: 0.519118
# [700]	valid_0's r2_score: 0.520026
# [800]	valid_0's r2_score: 0.521027
# [900]	valid_0's r2_score: 0.521959
# [1000]	valid_0's r2_score: 0.522555
# [1100]	valid_0's r2_score: 0.522765
# [1200]	valid_0's r2_score: 0.522971
# [1300]	valid_0's r2_score: 0.523268
# [1400]	valid_0's r2_score: 0.523449
# [1500]	valid_0's r2_score: 0.523675
# [1600]	valid_0's r2_score: 0.523851
# [1700]	valid_0's r2_score: 0.523916
# [1800]	valid_0's r2_score: 0.523857
# Early stopping, best iteration is:
# [1720]	valid_0's r2_score: 0.524064
# 0.690460996827
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.945693
# [200]	valid_0's r2_score: 0.951825
# [300]	valid_0's r2_score: 0.953683
# [400]	valid_0's r2_score: 0.954164
# [500]	valid_0's r2_score: 0.954514
# [600]	valid_0's r2_score: 0.954415
# Early stopping, best iteration is:
# [500]	valid_0's r2_score: 0.954514
# 0.968646299327
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.911764
# [200]	valid_0's r2_score: 0.914091
# Early stopping, best iteration is:
# [144]	valid_0's r2_score: 0.914227
# 0.925915110141
# cv score:
# 0.870336277896
# current score: 0.8704605283115117, 5
# [0.98411832816171907, 0.94507922796137345, 0.69046099682657436, 0.96864629932721902, 0.92591511014085237]
# [673, 1026, 1720, 500, 144] 812.6
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.958398
# [200]	valid_0's r2_score: 0.965732
# [300]	valid_0's r2_score: 0.968108
# [400]	valid_0's r2_score: 0.969744
# [500]	valid_0's r2_score: 0.970409
# [600]	valid_0's r2_score: 0.970992
# [700]	valid_0's r2_score: 0.971003
# [800]	valid_0's r2_score: 0.971204
# [900]	valid_0's r2_score: 0.97125
# [1000]	valid_0's r2_score: 0.971262
# Early stopping, best iteration is:
# [930]	valid_0's r2_score: 0.971353
# 0.984964833847
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.907729
# [200]	valid_0's r2_score: 0.913805
# [300]	valid_0's r2_score: 0.916323
# [400]	valid_0's r2_score: 0.917586
# [500]	valid_0's r2_score: 0.917896
# [600]	valid_0's r2_score: 0.918192
# [700]	valid_0's r2_score: 0.91851
# [800]	valid_0's r2_score: 0.918526
# [900]	valid_0's r2_score: 0.918772
# Early stopping, best iteration is:
# [883]	valid_0's r2_score: 0.918844
# 0.942374143885
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.510108
# [200]	valid_0's r2_score: 0.514015
# [300]	valid_0's r2_score: 0.515276
# [400]	valid_0's r2_score: 0.516353
# [500]	valid_0's r2_score: 0.516927
# [600]	valid_0's r2_score: 0.518059
# [700]	valid_0's r2_score: 0.518644
# [800]	valid_0's r2_score: 0.519301
# [900]	valid_0's r2_score: 0.519718
# [1000]	valid_0's r2_score: 0.520164
# [1100]	valid_0's r2_score: 0.520459
# [1200]	valid_0's r2_score: 0.521017
# [1300]	valid_0's r2_score: 0.521364
# [1400]	valid_0's r2_score: 0.521532
# [1500]	valid_0's r2_score: 0.521665
# [1600]	valid_0's r2_score: 0.52207
# [1700]	valid_0's r2_score: 0.522037
# Early stopping, best iteration is:
# [1602]	valid_0's r2_score: 0.522104
# 0.683625434166
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.945374
# [200]	valid_0's r2_score: 0.951764
# [300]	valid_0's r2_score: 0.953786
# [400]	valid_0's r2_score: 0.954608
# [500]	valid_0's r2_score: 0.954541
# Early stopping, best iteration is:
# [429]	valid_0's r2_score: 0.95473
# 0.968190228332
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.91347
# [200]	valid_0's r2_score: 0.915572
# Early stopping, best iteration is:
# [175]	valid_0's r2_score: 0.915711
# 0.92775534873
# cv score:
# 0.868030051441
# current score: 0.8701123188901225, 6
# [0.98496483384726174, 0.94237414388460761, 0.68362543416634336, 0.96819022833196633, 0.92775534873016752]
# [930, 883, 1602, 429, 175] 803.8
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.957817
# [200]	valid_0's r2_score: 0.96513
# [300]	valid_0's r2_score: 0.967936
# [400]	valid_0's r2_score: 0.969389
# [500]	valid_0's r2_score: 0.970481
# [600]	valid_0's r2_score: 0.971511
# [700]	valid_0's r2_score: 0.971831
# [800]	valid_0's r2_score: 0.97201
# [900]	valid_0's r2_score: 0.971975
# Early stopping, best iteration is:
# [809]	valid_0's r2_score: 0.972057
# 0.985090285007
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.907922
# [200]	valid_0's r2_score: 0.914138
# [300]	valid_0's r2_score: 0.916599
# [400]	valid_0's r2_score: 0.917619
# [500]	valid_0's r2_score: 0.918055
# [600]	valid_0's r2_score: 0.918525
# [700]	valid_0's r2_score: 0.918714
# [800]	valid_0's r2_score: 0.91897
# [900]	valid_0's r2_score: 0.919116
# [1000]	valid_0's r2_score: 0.919116
# Early stopping, best iteration is:
# [909]	valid_0's r2_score: 0.919176
# 0.943020612939
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.510984
# [200]	valid_0's r2_score: 0.513571
# [300]	valid_0's r2_score: 0.514575
# [400]	valid_0's r2_score: 0.515817
# [500]	valid_0's r2_score: 0.516588
# [600]	valid_0's r2_score: 0.51749
# [700]	valid_0's r2_score: 0.518146
# [800]	valid_0's r2_score: 0.519116
# [900]	valid_0's r2_score: 0.519737
# [1000]	valid_0's r2_score: 0.520068
# [1100]	valid_0's r2_score: 0.520453
# [1200]	valid_0's r2_score: 0.521027
# [1300]	valid_0's r2_score: 0.521178
# [1400]	valid_0's r2_score: 0.521564
# [1500]	valid_0's r2_score: 0.522339
# [1600]	valid_0's r2_score: 0.522728
# Early stopping, best iteration is:
# [1574]	valid_0's r2_score: 0.522735
# 0.681911987589
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.94575
# [200]	valid_0's r2_score: 0.952236
# [300]	valid_0's r2_score: 0.953707
# [400]	valid_0's r2_score: 0.954535
# [500]	valid_0's r2_score: 0.954667
# Early stopping, best iteration is:
# [463]	valid_0's r2_score: 0.954943
# 0.968558490527
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.911864
# [200]	valid_0's r2_score: 0.914203
# Early stopping, best iteration is:
# [167]	valid_0's r2_score: 0.914466
# 0.927991676008
# cv score:
# 0.867726255002
# current score: 0.8698181334322167, 7
# [0.98509028500678797, 0.94302061293911188, 0.68191198758892546, 0.96855849052695964, 0.92799167600787158]
# [809, 909, 1574, 463, 167] 784.4
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.957597
# [200]	valid_0's r2_score: 0.966426
# [300]	valid_0's r2_score: 0.969085
# [400]	valid_0's r2_score: 0.970119
# [500]	valid_0's r2_score: 0.970886
# [600]	valid_0's r2_score: 0.971552
# [700]	valid_0's r2_score: 0.971845
# [800]	valid_0's r2_score: 0.971998
# Early stopping, best iteration is:
# [746]	valid_0's r2_score: 0.972065
# 0.984575846415
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.90644
# [200]	valid_0's r2_score: 0.912818
# [300]	valid_0's r2_score: 0.91549
# [400]	valid_0's r2_score: 0.916562
# [500]	valid_0's r2_score: 0.917104
# [600]	valid_0's r2_score: 0.917653
# [700]	valid_0's r2_score: 0.917938
# [800]	valid_0's r2_score: 0.918008
# Early stopping, best iteration is:
# [713]	valid_0's r2_score: 0.918059
# 0.938918821357
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.509596
# [200]	valid_0's r2_score: 0.512924
# [300]	valid_0's r2_score: 0.514439
# [400]	valid_0's r2_score: 0.515796
# [500]	valid_0's r2_score: 0.517005
# [600]	valid_0's r2_score: 0.517592
# [700]	valid_0's r2_score: 0.518584
# [800]	valid_0's r2_score: 0.51945
# [900]	valid_0's r2_score: 0.519668
# [1000]	valid_0's r2_score: 0.52041
# [1100]	valid_0's r2_score: 0.52106
# [1200]	valid_0's r2_score: 0.521748
# [1300]	valid_0's r2_score: 0.522065
# [1400]	valid_0's r2_score: 0.522387
# [1500]	valid_0's r2_score: 0.522802
# [1600]	valid_0's r2_score: 0.522771
# Early stopping, best iteration is:
# [1526]	valid_0's r2_score: 0.522984
# 0.67897395405
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.944351
# [200]	valid_0's r2_score: 0.951328
# [300]	valid_0's r2_score: 0.95324
# [400]	valid_0's r2_score: 0.953939
# [500]	valid_0's r2_score: 0.954165
# [600]	valid_0's r2_score: 0.954299
# Early stopping, best iteration is:
# [544]	valid_0's r2_score: 0.954342
# 0.9691154501
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.912704
# [200]	valid_0's r2_score: 0.915372
# [300]	valid_0's r2_score: 0.915296
# Early stopping, best iteration is:
# [231]	valid_0's r2_score: 0.915593
# 0.93007653549
# cv score:
# 0.866394819998
# current score: 0.8694328808669674, 8
# [0.98457584641508178, 0.93891882135669735, 0.67897395404958527, 0.96911545010001066, 0.93007653549034164]
# [746, 713, 1526, 544, 231] 752.0
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.957449
# [200]	valid_0's r2_score: 0.96491
# [300]	valid_0's r2_score: 0.968521
# [400]	valid_0's r2_score: 0.970277
# [500]	valid_0's r2_score: 0.97109
# [600]	valid_0's r2_score: 0.971885
# [700]	valid_0's r2_score: 0.971923
# Early stopping, best iteration is:
# [665]	valid_0's r2_score: 0.971949
# 0.983981917887
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.905664
# [200]	valid_0's r2_score: 0.912501
# [300]	valid_0's r2_score: 0.915006
# [400]	valid_0's r2_score: 0.916284
# [500]	valid_0's r2_score: 0.917399
# [600]	valid_0's r2_score: 0.9175
# [700]	valid_0's r2_score: 0.917931
# [800]	valid_0's r2_score: 0.918023
# [900]	valid_0's r2_score: 0.918204
# [1000]	valid_0's r2_score: 0.918317
# [1100]	valid_0's r2_score: 0.918382
# [1200]	valid_0's r2_score: 0.918358
# [1300]	valid_0's r2_score: 0.918616
# Early stopping, best iteration is:
# [1293]	valid_0's r2_score: 0.918661
# 0.948661026019
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.509118
# [200]	valid_0's r2_score: 0.512835
# [300]	valid_0's r2_score: 0.514797
# [400]	valid_0's r2_score: 0.515698
# [500]	valid_0's r2_score: 0.517065
# [600]	valid_0's r2_score: 0.518333
# [700]	valid_0's r2_score: 0.518995
# [800]	valid_0's r2_score: 0.519617
# [900]	valid_0's r2_score: 0.520352
# [1000]	valid_0's r2_score: 0.521287
# [1100]	valid_0's r2_score: 0.521518
# [1200]	valid_0's r2_score: 0.521961
# [1300]	valid_0's r2_score: 0.52223
# [1400]	valid_0's r2_score: 0.522549
# [1500]	valid_0's r2_score: 0.52247
# Early stopping, best iteration is:
# [1410]	valid_0's r2_score: 0.522678
# 0.671703245202
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.940884
# [200]	valid_0's r2_score: 0.94835
# [300]	valid_0's r2_score: 0.950761
# [400]	valid_0's r2_score: 0.952367
# [500]	valid_0's r2_score: 0.952528
# Early stopping, best iteration is:
# [488]	valid_0's r2_score: 0.95266
# 0.96820457452
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.911298
# [200]	valid_0's r2_score: 0.913882
# [300]	valid_0's r2_score: 0.913248
# Early stopping, best iteration is:
# [209]	valid_0's r2_score: 0.913982
# 0.927772304299
# cv score:
# 0.865272586735
# current score: 0.8690208040425328, 9
# [0.98398191788723399, 0.94866102601866864, 0.67170324520227132, 0.96820457452032871, 0.92777230429910884]
# [665, 1293, 1410, 488, 209] 813.0
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.958243
# [200]	valid_0's r2_score: 0.965837
# [300]	valid_0's r2_score: 0.968361
# [400]	valid_0's r2_score: 0.96988
# [500]	valid_0's r2_score: 0.970528
# [600]	valid_0's r2_score: 0.970959
# [700]	valid_0's r2_score: 0.97122
# [800]	valid_0's r2_score: 0.971702
# Early stopping, best iteration is:
# [781]	valid_0's r2_score: 0.971742
# 0.984394588302
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.908191
# [200]	valid_0's r2_score: 0.914088
# [300]	valid_0's r2_score: 0.916543
# [400]	valid_0's r2_score: 0.91777
# [500]	valid_0's r2_score: 0.918334
# [600]	valid_0's r2_score: 0.918616
# [700]	valid_0's r2_score: 0.91876
# [800]	valid_0's r2_score: 0.918931
# [900]	valid_0's r2_score: 0.919003
# [1000]	valid_0's r2_score: 0.919236
# [1100]	valid_0's r2_score: 0.919332
# [1200]	valid_0's r2_score: 0.919226
# Early stopping, best iteration is:
# [1120]	valid_0's r2_score: 0.919363
# 0.946445531148
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.508881
# [200]	valid_0's r2_score: 0.512807
# [300]	valid_0's r2_score: 0.514955
# [400]	valid_0's r2_score: 0.516774
# [500]	valid_0's r2_score: 0.517602
# [600]	valid_0's r2_score: 0.518411
# [700]	valid_0's r2_score: 0.519973
# [800]	valid_0's r2_score: 0.520805
# [900]	valid_0's r2_score: 0.521393
# [1000]	valid_0's r2_score: 0.522063
# [1100]	valid_0's r2_score: 0.522363
# [1200]	valid_0's r2_score: 0.522941
# [1300]	valid_0's r2_score: 0.523217
# [1400]	valid_0's r2_score: 0.52332
# [1500]	valid_0's r2_score: 0.52333
# Early stopping, best iteration is:
# [1437]	valid_0's r2_score: 0.523544
# 0.674043519997
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.944856
# [200]	valid_0's r2_score: 0.951218
# [300]	valid_0's r2_score: 0.953329
# [400]	valid_0's r2_score: 0.95374
# [500]	valid_0's r2_score: 0.953918
# [600]	valid_0's r2_score: 0.953754
# Early stopping, best iteration is:
# [548]	valid_0's r2_score: 0.95408
# 0.969347449893
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.911621
# [200]	valid_0's r2_score: 0.914547
# [300]	valid_0's r2_score: 0.913645
# Early stopping, best iteration is:
# [203]	valid_0's r2_score: 0.914594
# 0.928865778749
# cv score:
# 0.866040218617
# current score: 0.8687538707258542, 10
# [0.98439458830225746, 0.94644553114797048, 0.67404351999662326, 0.96934744989322363, 0.92886577874944065]
# [781, 1120, 1437, 548, 203] 817.8
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.959098
# [200]	valid_0's r2_score: 0.967
# [300]	valid_0's r2_score: 0.96921
# [400]	valid_0's r2_score: 0.970173
# [500]	valid_0's r2_score: 0.970964
# [600]	valid_0's r2_score: 0.971607
# [700]	valid_0's r2_score: 0.971667
# Early stopping, best iteration is:
# [645]	valid_0's r2_score: 0.971816
# 0.98398658392
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.907306
# [200]	valid_0's r2_score: 0.913669
# [300]	valid_0's r2_score: 0.916287
# [400]	valid_0's r2_score: 0.917413
# [500]	valid_0's r2_score: 0.917937
# [600]	valid_0's r2_score: 0.918465
# [700]	valid_0's r2_score: 0.918623
# [800]	valid_0's r2_score: 0.918883
# [900]	valid_0's r2_score: 0.918731
# Early stopping, best iteration is:
# [800]	valid_0's r2_score: 0.918883
# 0.941244396165
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.50835
# [200]	valid_0's r2_score: 0.512968
# [300]	valid_0's r2_score: 0.514835
# [400]	valid_0's r2_score: 0.516365
# [500]	valid_0's r2_score: 0.517471
# [600]	valid_0's r2_score: 0.518594
# [700]	valid_0's r2_score: 0.519676
# [800]	valid_0's r2_score: 0.520217
# [900]	valid_0's r2_score: 0.520833
# [1000]	valid_0's r2_score: 0.521426
# [1100]	valid_0's r2_score: 0.521858
# [1200]	valid_0's r2_score: 0.522251
# [1300]	valid_0's r2_score: 0.522593
# [1400]	valid_0's r2_score: 0.522986
# [1500]	valid_0's r2_score: 0.523412
# [1600]	valid_0's r2_score: 0.523506
# [1700]	valid_0's r2_score: 0.523642
# [1800]	valid_0's r2_score: 0.523753
# Early stopping, best iteration is:
# [1761]	valid_0's r2_score: 0.523877
# 0.692848363166
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.94394
# [200]	valid_0's r2_score: 0.950848
# [300]	valid_0's r2_score: 0.953104
# [400]	valid_0's r2_score: 0.95356
# Early stopping, best iteration is:
# [396]	valid_0's r2_score: 0.953653
# 0.966818765119
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.910414
# [200]	valid_0's r2_score: 0.91356
# [300]	valid_0's r2_score: 0.913801
# Early stopping, best iteration is:
# [266]	valid_0's r2_score: 0.914001
# 0.930840752346
# cv score:
# 0.870934752376
# current score: 0.8689879342528615, 11
# [0.98398658392014682, 0.94124439616530919, 0.69284836316562926, 0.96681876511947007, 0.93084075234554586]
# [645, 800, 1761, 396, 266] 773.6
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.960493
# [200]	valid_0's r2_score: 0.967416
# [300]	valid_0's r2_score: 0.969734
# [400]	valid_0's r2_score: 0.970959
# [500]	valid_0's r2_score: 0.971744
# [600]	valid_0's r2_score: 0.972008
# [700]	valid_0's r2_score: 0.972392
# Early stopping, best iteration is:
# [690]	valid_0's r2_score: 0.972516
# 0.983731649694
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.907264
# [200]	valid_0's r2_score: 0.913656
# [300]	valid_0's r2_score: 0.915733
# [400]	valid_0's r2_score: 0.91712
# [500]	valid_0's r2_score: 0.917735
# [600]	valid_0's r2_score: 0.918293
# [700]	valid_0's r2_score: 0.918355
# [800]	valid_0's r2_score: 0.918692
# [900]	valid_0's r2_score: 0.918651
# Early stopping, best iteration is:
# [809]	valid_0's r2_score: 0.918736
# 0.941042910094
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.509088
# [200]	valid_0's r2_score: 0.513384
# [300]	valid_0's r2_score: 0.515065
# [400]	valid_0's r2_score: 0.516282
# [500]	valid_0's r2_score: 0.516706
# [600]	valid_0's r2_score: 0.518427
# [700]	valid_0's r2_score: 0.518923
# [800]	valid_0's r2_score: 0.519705
# [900]	valid_0's r2_score: 0.520083
# [1000]	valid_0's r2_score: 0.521016
# [1100]	valid_0's r2_score: 0.521231
# [1200]	valid_0's r2_score: 0.52147
# [1300]	valid_0's r2_score: 0.521656
# [1400]	valid_0's r2_score: 0.522081
# [1500]	valid_0's r2_score: 0.522244
# [1600]	valid_0's r2_score: 0.522297
# [1700]	valid_0's r2_score: 0.522486
# [1800]	valid_0's r2_score: 0.522767
# Early stopping, best iteration is:
# [1799]	valid_0's r2_score: 0.522774
# 0.695986029761
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.944676
# [200]	valid_0's r2_score: 0.951217
# [300]	valid_0's r2_score: 0.953074
# [400]	valid_0's r2_score: 0.953791
# [500]	valid_0's r2_score: 0.953663
# Early stopping, best iteration is:
# [427]	valid_0's r2_score: 0.953929
# 0.967749854437
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.911695
# [200]	valid_0's r2_score: 0.914409
# [300]	valid_0's r2_score: 0.914167
# Early stopping, best iteration is:
# [232]	valid_0's r2_score: 0.914661
# 0.929605148862
# cv score:
# 0.87178709899
# current score: 0.8692495968314169, 12
# [0.98373164969428473, 0.94104291009369245, 0.69598602976120305, 0.96774985443694772, 0.92960514886157131]
# [690, 809, 1799, 427, 232] 791.4
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.959505
# [200]	valid_0's r2_score: 0.966862
# [300]	valid_0's r2_score: 0.969453
# [400]	valid_0's r2_score: 0.9706
# [500]	valid_0's r2_score: 0.971682
# [600]	valid_0's r2_score: 0.97187
# [700]	valid_0's r2_score: 0.972136
# Early stopping, best iteration is:
# [699]	valid_0's r2_score: 0.972141
# 0.983920195492
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.907467
# [200]	valid_0's r2_score: 0.913193
# [300]	valid_0's r2_score: 0.915711
# [400]	valid_0's r2_score: 0.916912
# [500]	valid_0's r2_score: 0.917426
# [600]	valid_0's r2_score: 0.917787
# [700]	valid_0's r2_score: 0.918218
# Early stopping, best iteration is:
# [689]	valid_0's r2_score: 0.91829
# 0.939010751906
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.510354
# [200]	valid_0's r2_score: 0.5142
# [300]	valid_0's r2_score: 0.515405
# [400]	valid_0's r2_score: 0.51701
# [500]	valid_0's r2_score: 0.517933
# [600]	valid_0's r2_score: 0.519006
# [700]	valid_0's r2_score: 0.51959
# [800]	valid_0's r2_score: 0.520597
# [900]	valid_0's r2_score: 0.520682
# [1000]	valid_0's r2_score: 0.521232
# [1100]	valid_0's r2_score: 0.521885
# [1200]	valid_0's r2_score: 0.522228
# [1300]	valid_0's r2_score: 0.52236
# Early stopping, best iteration is:
# [1279]	valid_0's r2_score: 0.522526
# 0.663731162621
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.946065
# [200]	valid_0's r2_score: 0.951949
# [300]	valid_0's r2_score: 0.953714
# [400]	valid_0's r2_score: 0.954482
# [500]	valid_0's r2_score: 0.954401
# Early stopping, best iteration is:
# [454]	valid_0's r2_score: 0.954628
# 0.968430950398
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.912327
# [200]	valid_0's r2_score: 0.915391
# [300]	valid_0's r2_score: 0.915376
# Early stopping, best iteration is:
# [241]	valid_0's r2_score: 0.915596
# 0.932123249665
# cv score:
# 0.861706902791
# current score: 0.8687152844720375, 13
# [0.98392019549217202, 0.93901075190605565, 0.66373116262082066, 0.96843095039751492, 0.93212324966521309]
# [699, 689, 1279, 454, 241] 672.4
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.959879
# [200]	valid_0's r2_score: 0.967287
# [300]	valid_0's r2_score: 0.969939
# [400]	valid_0's r2_score: 0.971178
# [500]	valid_0's r2_score: 0.972323
# [600]	valid_0's r2_score: 0.972862
# [700]	valid_0's r2_score: 0.973455
# [800]	valid_0's r2_score: 0.973561
# [900]	valid_0's r2_score: 0.973462
# Early stopping, best iteration is:
# [803]	valid_0's r2_score: 0.973588
# 0.984506517571
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.906002
# [200]	valid_0's r2_score: 0.913042
# [300]	valid_0's r2_score: 0.91595
# [400]	valid_0's r2_score: 0.917029
# [500]	valid_0's r2_score: 0.917895
# [600]	valid_0's r2_score: 0.918161
# [700]	valid_0's r2_score: 0.918369
# [800]	valid_0's r2_score: 0.918612
# [900]	valid_0's r2_score: 0.918599
# Early stopping, best iteration is:
# [862]	valid_0's r2_score: 0.91873
# 0.940934430235
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.508764
# [200]	valid_0's r2_score: 0.513504
# [300]	valid_0's r2_score: 0.515723
# [400]	valid_0's r2_score: 0.516739
# [500]	valid_0's r2_score: 0.517787
# [600]	valid_0's r2_score: 0.519124
# [700]	valid_0's r2_score: 0.520278
# [800]	valid_0's r2_score: 0.520654
# [900]	valid_0's r2_score: 0.521478
# [1000]	valid_0's r2_score: 0.522014
# [1100]	valid_0's r2_score: 0.522601
# [1200]	valid_0's r2_score: 0.522785
# Early stopping, best iteration is:
# [1134]	valid_0's r2_score: 0.522848
# 0.650637892183
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.943088
# [200]	valid_0's r2_score: 0.949978
# [300]	valid_0's r2_score: 0.951996
# [400]	valid_0's r2_score: 0.953379
# [500]	valid_0's r2_score: 0.954009
# [600]	valid_0's r2_score: 0.953976
# Early stopping, best iteration is:
# [521]	valid_0's r2_score: 0.954159
# 0.96804988009
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.910686
# [200]	valid_0's r2_score: 0.914352
# [300]	valid_0's r2_score: 0.914029
# Early stopping, best iteration is:
# [203]	valid_0's r2_score: 0.914396
# 0.92709978289
# cv score:
# 0.857033758794
# current score: 0.8679273579255344, 14
# [0.98450651757089314, 0.94093443023501089, 0.65063789218292767, 0.96804988008991022, 0.92709978289007622]
# [803, 862, 1134, 521, 203] 704.6
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.959825
# [200]	valid_0's r2_score: 0.96749
# [300]	valid_0's r2_score: 0.970377
# [400]	valid_0's r2_score: 0.971511
# [500]	valid_0's r2_score: 0.972082
# [600]	valid_0's r2_score: 0.972719
# [700]	valid_0's r2_score: 0.972878
# [800]	valid_0's r2_score: 0.973086
# [900]	valid_0's r2_score: 0.972803
# Early stopping, best iteration is:
# [823]	valid_0's r2_score: 0.973169
# 0.984921253443
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.906338
# [200]	valid_0's r2_score: 0.913253
# [300]	valid_0's r2_score: 0.916697
# [400]	valid_0's r2_score: 0.918027
# [500]	valid_0's r2_score: 0.918617
# [600]	valid_0's r2_score: 0.919042
# [700]	valid_0's r2_score: 0.919153
# [800]	valid_0's r2_score: 0.919312
# [900]	valid_0's r2_score: 0.919321
# [1000]	valid_0's r2_score: 0.919516
# [1100]	valid_0's r2_score: 0.919702
# [1200]	valid_0's r2_score: 0.919777
# Early stopping, best iteration is:
# [1187]	valid_0's r2_score: 0.919827
# 0.947043848969
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.5084
# [200]	valid_0's r2_score: 0.513206
# [300]	valid_0's r2_score: 0.514769
# [400]	valid_0's r2_score: 0.515901
# [500]	valid_0's r2_score: 0.516845
# [600]	valid_0's r2_score: 0.518294
# [700]	valid_0's r2_score: 0.519697
# [800]	valid_0's r2_score: 0.520547
# [900]	valid_0's r2_score: 0.521343
# [1000]	valid_0's r2_score: 0.521526
# [1100]	valid_0's r2_score: 0.522102
# [1200]	valid_0's r2_score: 0.522672
# [1300]	valid_0's r2_score: 0.522991
# [1400]	valid_0's r2_score: 0.52324
# [1500]	valid_0's r2_score: 0.523542
# [1600]	valid_0's r2_score: 0.523882
# [1700]	valid_0's r2_score: 0.524272
# [1800]	valid_0's r2_score: 0.524349
# [1900]	valid_0's r2_score: 0.524327
# [2000]	valid_0's r2_score: 0.524235
# Early stopping, best iteration is:
# [1973]	valid_0's r2_score: 0.524421
# 0.704368439834
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.94447
# [200]	valid_0's r2_score: 0.951405
# [300]	valid_0's r2_score: 0.953517
# [400]	valid_0's r2_score: 0.954096
# [500]	valid_0's r2_score: 0.954164
# Early stopping, best iteration is:
# [454]	valid_0's r2_score: 0.954265
# 0.967591847258
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.911127
# [200]	valid_0's r2_score: 0.913275
# [300]	valid_0's r2_score: 0.912933
# Early stopping, best iteration is:
# [229]	valid_0's r2_score: 0.913441
# 0.928037247141
# cv score:
# 0.875472300887
# current score: 0.8684642466310487, 15
# [0.98492125344310966, 0.94704384896947358, 0.70436843983423936, 0.96759184725767633, 0.92803724714058189]
# [823, 1187, 1973, 454, 229] 933.2
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.959705
# [200]	valid_0's r2_score: 0.967063
# [300]	valid_0's r2_score: 0.969401
# [400]	valid_0's r2_score: 0.970316
# [500]	valid_0's r2_score: 0.971134
# [600]	valid_0's r2_score: 0.971702
# [700]	valid_0's r2_score: 0.971921
# [800]	valid_0's r2_score: 0.97189
# [900]	valid_0's r2_score: 0.972129
# [1000]	valid_0's r2_score: 0.97203
# Early stopping, best iteration is:
# [923]	valid_0's r2_score: 0.972263
# 0.985548912964
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.907509
# [200]	valid_0's r2_score: 0.91411
# [300]	valid_0's r2_score: 0.916181
# [400]	valid_0's r2_score: 0.917421
# [500]	valid_0's r2_score: 0.918056
# [600]	valid_0's r2_score: 0.918344
# [700]	valid_0's r2_score: 0.918542
# [800]	valid_0's r2_score: 0.918728
# [900]	valid_0's r2_score: 0.918713
# [1000]	valid_0's r2_score: 0.918954
# [1100]	valid_0's r2_score: 0.918999
# [1200]	valid_0's r2_score: 0.918993
# Early stopping, best iteration is:
# [1113]	valid_0's r2_score: 0.919102
# 0.946346200306
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.508923
# [200]	valid_0's r2_score: 0.512374
# [300]	valid_0's r2_score: 0.51362
# [400]	valid_0's r2_score: 0.51483
# [500]	valid_0's r2_score: 0.517295
# [600]	valid_0's r2_score: 0.518295
# [700]	valid_0's r2_score: 0.519068
# [800]	valid_0's r2_score: 0.519563
# [900]	valid_0's r2_score: 0.520186
# [1000]	valid_0's r2_score: 0.520686
# [1100]	valid_0's r2_score: 0.521397
# [1200]	valid_0's r2_score: 0.521887
# [1300]	valid_0's r2_score: 0.522231
# [1400]	valid_0's r2_score: 0.522711
# [1500]	valid_0's r2_score: 0.522732
# Early stopping, best iteration is:
# [1436]	valid_0's r2_score: 0.522934
# 0.672264833087
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.946659
# [200]	valid_0's r2_score: 0.953155
# [300]	valid_0's r2_score: 0.954561
# [400]	valid_0's r2_score: 0.955426
# [500]	valid_0's r2_score: 0.955571
# Early stopping, best iteration is:
# [491]	valid_0's r2_score: 0.955673
# 0.968913050889
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's r2_score: 0.912193
# [200]	valid_0's r2_score: 0.914842
# Early stopping, best iteration is:
# [158]	valid_0's r2_score: 0.915227
# 0.92640684594
# cv score:
# 0.86512548676
# current score: 0.8682814710759444, 16
# [0.9855489129638112, 0.94634620030552041, 0.67226483308676688, 0.96891305088934965, 0.9264068459395074]
# [923, 1113, 1436, 491, 158] 824.2
# [0.86718105143788626, 0.87039424116999853, 0.87089072271851231, 0.87160751430059413, 0.87033627789628443, 0.86803005144110656, 0.86772625500166911, 0.86639481999834245, 0.86527258673534679, 0.86604021861654745, 0.87093475237640927, 0.87178709899047224, 0.86170690279139028, 0.85703375879438792, 0.87547230088737116, 0.86512548675973511]

# %%
# Out:
# [0.80349530513470635, 0.8039473042563734, 0.80448919111181172, 0.80419915095861993, 0.80474068402778332, 0.80494204174302086, 0.8044695242240546, 0.80473218724268836, 0.80358720454025645, 0.80397121837732444, 0.80354318122148816, 0.80491646374082437, 0.80499737250244863, 0.80338203847812861, 0.80328379005776462, 0.80434391743912637, 0.80302947906255673, 0.80276325594428921, 0.80391398219772203, 0.80239363556266319, 0.80270574785605187, 0.80360201259231645, 0.80355928958237455, 0.80403982458980572, 0.80182961351662185, 0.80349180553133459, 0.80146816792541775, 0.80373744027418226, 0.80406613905910662, 0.80163064723346, 0.80221684558999262, 0.80333583341480674, 0.80645523439353473, 0.80691430711194989, 0.8069162011230655, 0.80661860497438143, 0.80753879751094337, 0.80735145097928518, 0.80684798617597431, 0.80784676186762683, 0.80673650717496659, 0.8067748469182715, 0.80726284452994912, 0.80669085359730075, 0.80740652597121021, 0.8062596546181845, 0.80738052309138575, 0.80705636748911413]

# %%
sub = pd.DataFrame({'portfolio_id':test_portfolio_id, 'return':final_cv_pred / 16.})
sub.head(5)
# Out:
#   portfolio_id    return
# 0   PF00001001  0.027708
# 1   PF00001004  0.028431
# 2   PF00001009  0.022581
# 3   PF00001013  0.028177
# 4   PF00001014  0.023978

# %%
sub.to_csv('lgb_cv_v2.csv', index=False)
